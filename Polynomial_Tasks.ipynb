# %% [markdown]
# <a href="https://colab.research.google.com/github/surekhavydyula4-cmd/ML/blob/main/Polynomial_Tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-08ae6f28-61ff-4545-bbc2-43f52720f837" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-08ae6f28-61ff-4545-bbc2-43f52720f837">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Sheet.csv")
print(df)
# Out:
#    Study_Hours  Marks
# 0            1      5
# 1            2     12
# 2            3     25
# 3            4     45
# 4            5     65
# 5            6     82
# 6            7     92
# 7            8     97
# 8            9     99
# 9           10    100

# %%
#Imorting Libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

#Dataframe creation
df=pd.read_csv("Sheet.csv")

#data
X=df.iloc[:,0:1]
y=df.iloc[:,1]

#Model training
lin=LinearRegression()
lin.fit(X,y)
print(lin.predict([[6.5]]))

#Plotting
plt.scatter(X, y, color="blue")
plt.plot(X, lin.predict(X), color="red")
plt.title("Linear Regression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [74.21212121]

# %%
#Importing Libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

#Dataframe creation
df=pd.read_csv("Sheet.csv")

#data
X=df.iloc[:,0:1]
y=df.iloc[:,1]

#Model training
pol=PolynomialFeatures(degree=2)
pol_lin=pol.fit_transform(X)

lin=LinearRegression()
lin.fit(pol_lin,y)

poi_pred = lin.predict(pol.transform([[6.5]]))
print(poi_pred)

#Plotting
plt.scatter(X, y, color="blue")
plt.plot(X, lin.predict(pol_lin), color="red")
plt.title("Linear Regression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# [81.59943182]

# %%
#Importing Libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

#Dataframe creation
df=pd.read_csv("Sheet.csv")

#data
X=df.iloc[:,0:1]
y=df.iloc[:,1]

#Model training
pol=PolynomialFeatures(degree=3)
pol_lin=pol.fit_transform(X)

lin=LinearRegression()
lin.fit(pol_lin,y)

poi_pred = lin.predict(pol.transform([[6.5]]))
print(poi_pred)

#Plotting
plt.scatter(X, y, color="blue")
plt.plot(X, lin.predict(pol_lin), color="red")
plt.title("Linear Regression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# [85.33541667]

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-774009d2-18f2-4f7c-b42f-9a4eb19c878a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-774009d2-18f2-4f7c-b42f-9a4eb19c878a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("Salaries.csv")
print(df)
# Out:
#    Experience  Salary
# 0           1    3000
# 1           2    3500
# 2           3    4000
# 3           4    5000
# 4           5    7000
# 5           6   10000
# 6           7   13000
# 7           8   16000
# 8           9   18000
# 9          10   20000

# %%
#Importing Libraries
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import pandas as pd
import matplotlib.pyplot as plt

#Dataframe creation
df=pd.read_csv("Salaries.csv")

#data
X=df.iloc[:,0:1]
y=df.iloc[:,1]

#Model training
pol=PolynomialFeatures(degree=3)
pol_lin=pol.fit_transform(X)

lin=LinearRegression()
lin.fit(pol_lin,y)

poi_pred = lin.predict(pol.transform([[6.5]]))
print(poi_pred)

#Plotting
plt.scatter(X, y, color="blue")
plt.plot(X, lin.predict(pol_lin), color="red")
plt.title("Linear Regression")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(
# [11460.41666667]
